# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergio-Deluich-Kaufmann/csci167-repository-sdk/blob/main/My%20Notebooks%20/%208.3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-he_effz4
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-he_effz4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c5cd893e2278d18c3b692d6871d439fbb6fd508045e6367755767fd8668c3fb0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ubn6mprm/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
'''
1. At what capacity will training error become zero?
Prediction: Training error will approach its minimum around n_hidden = 60-70 due to the 15% label noise preventing true zero error

2. At what capacity will the first minimum of test error appear?
Prediction: First minimum around n_hidden = 20-40 units in the under-parameterized regime.

3. At what capacity will the maximum of test error appear?
Prediction: Max test error around n_hidden = 60-80 units near the interpolation threshold.
'''
# Out:
# '\n1. At what capacity will training error become zero?\nPrediction: Training error will approach its minimum around n_hidden = 60-70 due to the 15% label noise preventing true zero error\n\n2. At what capacity will the first minimum of test error appear?\nPrediction: First minimum around n_hidden = 20-40 units in the under-parameterized regime.\n\n3. At what capacity will the maximum of test error appear?\nPrediction: Max test error around n_hidden = 60-80 units near the interpolation threshold.\n'

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299052, train error 89.25,  test loss 2.299160, test error 89.35
# Epoch   100, train loss 1.859481, train error 70.43,  test loss 1.705103, test error 68.45
# Epoch   200, train loss 1.852265, train error 70.25,  test loss 1.703349, test error 68.50
# Epoch   300, train loss 1.850447, train error 70.03,  test loss 1.709839, test error 68.00
# Epoch   400, train loss 1.849106, train error 69.57,  test loss 1.711294, test error 67.78
# Epoch   500, train loss 1.849211, train error 70.20,  test loss 1.713866, test error 67.65
# Epoch   600, train loss 1.853644, train error 70.30,  test loss 1.707260, test error 68.22
# Epoch   700, train loss 1.845338, train error 69.43,  test loss 1.700155, test error 68.72
# Epoch   800, train loss 1.846868, train error 69.72,  test loss 1.697006, test error 68.57
# Epoch   900, train loss 1.843443, train error 69.57,  test loss 1.709437, test error 68.50
# Training model with   4 hidden variables
# Epoch     0, train loss 2.294927, train error 88.07,  test loss 2.297616, test error 88.50
# Epoch   100, train loss 1.830357, train error 67.45,  test loss 1.706525, test error 65.88
# Epoch   200, train loss 1.796885, train error 65.72,  test loss 1.677558, test error 64.57
# Epoch   300, train loss 1.746215, train error 62.72,  test loss 1.608450, test error 60.80
# Epoch   400, train loss 1.738831, train error 62.00,  test loss 1.592423, test error 60.10
# Epoch   500, train loss 1.725141, train error 60.95,  test loss 1.578146, test error 58.70
# Epoch   600, train loss 1.723032, train error 60.97,  test loss 1.577698, test error 58.85
# Epoch   700, train loss 1.723000, train error 60.85,  test loss 1.581189, test error 58.95
# Epoch   800, train loss 1.726088, train error 61.10,  test loss 1.583117, test error 59.05
# Epoch   900, train loss 1.722447, train error 60.92,  test loss 1.577315, test error 58.85
# Training model with   6 hidden variables
# Epoch     0, train loss 2.306827, train error 87.28,  test loss 2.314494, test error 88.00
# Epoch   100, train loss 1.634011, train error 58.55,  test loss 1.475304, test error 57.20
# Epoch   200, train loss 1.625888, train error 58.38,  test loss 1.477604, test error 57.20
# Epoch   300, train loss 1.614477, train error 57.80,  test loss 1.472941, test error 56.67
# Epoch   400, train loss 1.609695, train error 57.78,  test loss 1.463974, test error 57.00
# Epoch   500, train loss 1.609420, train error 57.97,  test loss 1.460803, test error 56.65
# Epoch   600, train loss 1.603447, train error 57.67,  test loss 1.461305, test error 56.40
# Epoch   700, train loss 1.604936, train error 57.47,  test loss 1.471303, test error 56.72
# Epoch   800, train loss 1.604379, train error 57.12,  test loss 1.475149, test error 56.95
# Epoch   900, train loss 1.600853, train error 58.10,  test loss 1.466832, test error 56.30
# Training model with   8 hidden variables
# Epoch     0, train loss 2.260728, train error 85.18,  test loss 2.249670, test error 85.25
# Epoch   100, train loss 1.602295, train error 55.05,  test loss 1.431018, test error 54.35
# Epoch   200, train loss 1.558334, train error 54.17,  test loss 1.399507, test error 54.67
# Epoch   300, train loss 1.528597, train error 53.75,  test loss 1.398336, test error 54.83
# Epoch   400, train loss 1.540773, train error 54.72,  test loss 1.418029, test error 56.08
# Epoch   500, train loss 1.514032, train error 53.58,  test loss 1.402242, test error 54.42
# Epoch   600, train loss 1.508671, train error 53.15,  test loss 1.398648, test error 54.42
# Epoch   700, train loss 1.504256, train error 52.83,  test loss 1.401577, test error 54.58
# Epoch   800, train loss 1.500552, train error 52.35,  test loss 1.397540, test error 54.15
# Epoch   900, train loss 1.498560, train error 52.75,  test loss 1.409036, test error 54.60
# Training model with  10 hidden variables
# Epoch     0, train loss 2.197794, train error 83.68,  test loss 2.176481, test error 81.60
# Epoch   100, train loss 1.531423, train error 52.50,  test loss 1.363616, test error 50.92
# Epoch   200, train loss 1.438656, train error 49.00,  test loss 1.289014, test error 47.95
# Epoch   300, train loss 1.419396, train error 48.62,  test loss 1.300921, test error 48.03
# Epoch   400, train loss 1.409443, train error 47.75,  test loss 1.300114, test error 48.05
# Epoch   500, train loss 1.400689, train error 47.90,  test loss 1.318937, test error 48.95
# Epoch   600, train loss 1.401176, train error 48.20,  test loss 1.335401, test error 49.00
# Epoch   700, train loss 1.391038, train error 47.42,  test loss 1.330482, test error 48.97
# Epoch   800, train loss 1.386968, train error 48.17,  test loss 1.348127, test error 49.83
# Epoch   900, train loss 1.382239, train error 47.97,  test loss 1.356697, test error 48.97
# Training model with  14 hidden variables
# Epoch     0, train loss 2.273686, train error 86.20,  test loss 2.259523, test error 85.25
# Epoch   100, train loss 1.446408, train error 49.30,  test loss 1.335718, test error 50.40
# Epoch   200, train loss 1.334085, train error 44.62,  test loss 1.274804, test error 46.75
# Epoch   300, train loss 1.292539, train error 43.33,  test loss 1.281314, test error 46.70
# Epoch   400, train loss 1.279174, train error 43.40,  test loss 1.329295, test error 47.50
# Epoch   500, train loss 1.268861, train error 43.03,  test loss 1.353268, test error 47.85
# Epoch   600, train loss 1.259787, train error 42.67,  test loss 1.369071, test error 47.35
# Epoch   700, train loss 1.254344, train error 43.10,  test loss 1.396645, test error 48.17
# Epoch   800, train loss 1.249593, train error 42.22,  test loss 1.410996, test error 48.88
# Epoch   900, train loss 1.242674, train error 42.15,  test loss 1.427392, test error 49.25
# Training model with  18 hidden variables
# Epoch     0, train loss 2.176700, train error 81.15,  test loss 2.139341, test error 80.25
# Epoch   100, train loss 1.386513, train error 47.28,  test loss 1.402903, test error 53.00
# Epoch   200, train loss 1.274786, train error 43.08,  test loss 1.385217, test error 51.30
# Epoch   300, train loss 1.212134, train error 41.55,  test loss 1.408731, test error 51.25
# Epoch   400, train loss 1.185791, train error 40.47,  test loss 1.440868, test error 51.35
# Epoch   500, train loss 1.173539, train error 39.58,  test loss 1.480076, test error 52.38
# Epoch   600, train loss 1.173514, train error 39.58,  test loss 1.498336, test error 53.28
# Epoch   700, train loss 1.159089, train error 38.78,  test loss 1.527054, test error 52.05
# Epoch   800, train loss 1.156550, train error 39.08,  test loss 1.530745, test error 51.85
# Epoch   900, train loss 1.148873, train error 38.58,  test loss 1.542062, test error 51.83
# Training model with  22 hidden variables
# Epoch     0, train loss 2.167436, train error 80.95,  test loss 2.142632, test error 80.55
# Epoch   100, train loss 1.237273, train error 40.83,  test loss 1.240652, test error 46.22
# Epoch   200, train loss 1.132812, train error 38.12,  test loss 1.320061, test error 47.65
# Epoch   300, train loss 1.074152, train error 36.65,  test loss 1.401117, test error 48.25
# Epoch   400, train loss 1.041644, train error 35.25,  test loss 1.445118, test error 48.90
# Epoch   500, train loss 1.011531, train error 34.28,  test loss 1.497974, test error 49.42
# Epoch   600, train loss 0.996842, train error 32.80,  test loss 1.522668, test error 49.10
# Epoch   700, train loss 0.991328, train error 33.50,  test loss 1.571174, test error 49.05
# Epoch   800, train loss 0.976295, train error 33.43,  test loss 1.588381, test error 48.70
# Epoch   900, train loss 0.960436, train error 32.40,  test loss 1.634053, test error 49.80
# Training model with  26 hidden variables
# Epoch     0, train loss 2.184295, train error 81.03,  test loss 2.163792, test error 80.07
# Epoch   100, train loss 1.168027, train error 38.15,  test loss 1.274201, test error 48.42
# Epoch   200, train loss 1.031228, train error 34.12,  test loss 1.353155, test error 48.90
# Epoch   300, train loss 0.953508, train error 31.90,  test loss 1.431471, test error 48.47
# Epoch   400, train loss 0.916078, train error 31.00,  test loss 1.554805, test error 49.78
# Epoch   500, train loss 0.879698, train error 28.95,  test loss 1.606037, test error 50.10
# Epoch   600, train loss 0.862663, train error 28.62,  test loss 1.667164, test error 50.72
# Epoch   700, train loss 0.843530, train error 27.65,  test loss 1.740458, test error 51.40
# Epoch   800, train loss 0.826980, train error 27.68,  test loss 1.789923, test error 51.85
# Epoch   900, train loss 0.820090, train error 27.70,  test loss 1.856011, test error 52.05
# Training model with  30 hidden variables
# Epoch     0, train loss 2.172349, train error 81.03,  test loss 2.144502, test error 79.15
# Epoch   100, train loss 1.083732, train error 34.70,  test loss 1.339613, test error 48.17
# Epoch   200, train loss 0.899038, train error 29.75,  test loss 1.517594, test error 48.78
# Epoch   300, train loss 0.815662, train error 27.68,  test loss 1.729214, test error 51.03
# Epoch   400, train loss 0.777333, train error 26.20,  test loss 1.891038, test error 52.05
# Epoch   500, train loss 0.713607, train error 23.53,  test loss 2.070744, test error 53.10
# Epoch   600, train loss 0.708625, train error 24.05,  test loss 2.243027, test error 53.75
# Epoch   700, train loss 0.671992, train error 22.05,  test loss 2.375488, test error 54.65
# Epoch   800, train loss 0.665090, train error 22.50,  test loss 2.477698, test error 54.80
# Epoch   900, train loss 0.660072, train error 22.65,  test loss 2.542170, test error 54.30
# Training model with  35 hidden variables
# Epoch     0, train loss 2.108854, train error 78.68,  test loss 2.067224, test error 78.22
# Epoch   100, train loss 1.001646, train error 32.55,  test loss 1.361291, test error 48.30
# Epoch   200, train loss 0.804958, train error 26.38,  test loss 1.675426, test error 51.30
# Epoch   300, train loss 0.682936, train error 21.75,  test loss 2.011487, test error 52.30
# Epoch   400, train loss 0.629020, train error 20.95,  test loss 2.327641, test error 53.50
# Epoch   500, train loss 0.585928, train error 19.97,  test loss 2.603072, test error 54.55
# Epoch   600, train loss 0.519554, train error 16.60,  test loss 2.910990, test error 55.17
# Epoch   700, train loss 0.521538, train error 17.35,  test loss 3.197242, test error 55.33
# Epoch   800, train loss 0.493749, train error 15.72,  test loss 3.429361, test error 55.97
# Epoch   900, train loss 0.498025, train error 16.45,  test loss 3.648903, test error 56.60
# Training model with  40 hidden variables
# Epoch     0, train loss 2.149264, train error 79.55,  test loss 2.121415, test error 78.10
# Epoch   100, train loss 0.898564, train error 28.93,  test loss 1.389572, test error 48.47
# Epoch   200, train loss 0.617152, train error 19.00,  test loss 1.818776, test error 50.62
# Epoch   300, train loss 0.470862, train error 15.38,  test loss 2.486079, test error 52.15
# Epoch   400, train loss 0.373656, train error 12.60,  test loss 3.222848, test error 53.35
# Epoch   500, train loss 0.295577, train error 9.75,  test loss 4.080636, test error 53.90
# Epoch   600, train loss 0.291308, train error 10.38,  test loss 4.818715, test error 54.30
# Epoch   700, train loss 0.284148, train error 10.43,  test loss 5.588939, test error 54.92
# Epoch   800, train loss 0.205630, train error 7.22,  test loss 6.197339, test error 55.10
# Epoch   900, train loss 0.230382, train error 8.57,  test loss 6.808304, test error 55.38
# Training model with  45 hidden variables
# Epoch     0, train loss 2.144191, train error 78.90,  test loss 2.110146, test error 78.18
# Epoch   100, train loss 0.802781, train error 24.88,  test loss 1.486989, test error 49.15
# Epoch   200, train loss 0.491410, train error 14.10,  test loss 2.221223, test error 52.03
# Epoch   300, train loss 0.332879, train error 9.90,  test loss 3.227011, test error 54.22
# Epoch   400, train loss 0.241651, train error 7.88,  test loss 4.535282, test error 55.88
# Epoch   500, train loss 0.193923, train error 6.12,  test loss 5.728348, test error 55.95
# Epoch   600, train loss 0.210295, train error 8.00,  test loss 7.031275, test error 56.10
# Epoch   700, train loss 0.016710, train error 0.00,  test loss 8.033364, test error 56.88
# Epoch   800, train loss 0.009934, train error 0.00,  test loss 8.814840, test error 56.97
# Epoch   900, train loss 0.007192, train error 0.00,  test loss 9.386028, test error 57.00
# Training model with  50 hidden variables
# Epoch     0, train loss 2.085160, train error 78.25,  test loss 2.073497, test error 80.03
# Epoch   100, train loss 0.743565, train error 23.18,  test loss 1.531490, test error 49.85
# Epoch   200, train loss 0.365117, train error 10.75,  test loss 2.638305, test error 55.40
# Epoch   300, train loss 0.169704, train error 4.28,  test loss 4.149586, test error 56.08
# Epoch   400, train loss 0.047573, train error 0.25,  test loss 5.785791, test error 56.22
# Epoch   500, train loss 0.015811, train error 0.00,  test loss 6.887707, test error 57.00
# Epoch   600, train loss 0.009459, train error 0.00,  test loss 7.585917, test error 56.67
# Epoch   700, train loss 0.006772, train error 0.00,  test loss 8.091596, test error 56.80
# Epoch   800, train loss 0.005138, train error 0.00,  test loss 8.509134, test error 56.88
# Epoch   900, train loss 0.004162, train error 0.00,  test loss 8.849235, test error 56.83
# Training model with  55 hidden variables
# Epoch     0, train loss 2.059976, train error 76.68,  test loss 1.999894, test error 76.72
# Epoch   100, train loss 0.630213, train error 19.22,  test loss 1.663690, test error 51.08
# Epoch   200, train loss 0.207197, train error 4.47,  test loss 3.036967, test error 53.53
# Epoch   300, train loss 0.042168, train error 0.10,  test loss 4.781268, test error 54.30
# Epoch   400, train loss 0.014543, train error 0.00,  test loss 5.867904, test error 54.78
# Epoch   500, train loss 0.008447, train error 0.00,  test loss 6.518570, test error 54.58
# Epoch   600, train loss 0.005779, train error 0.00,  test loss 6.980452, test error 54.65
# Epoch   700, train loss 0.004337, train error 0.00,  test loss 7.337945, test error 54.45
# Epoch   800, train loss 0.003420, train error 0.00,  test loss 7.629450, test error 54.47
# Epoch   900, train loss 0.002807, train error 0.00,  test loss 7.874026, test error 54.50
# Training model with  60 hidden variables
# Epoch     0, train loss 2.068532, train error 77.07,  test loss 2.020931, test error 76.10
# Epoch   100, train loss 0.502576, train error 14.07,  test loss 1.804669, test error 52.03
# Epoch   200, train loss 0.101222, train error 0.88,  test loss 3.497774, test error 53.97
# Epoch   300, train loss 0.020415, train error 0.00,  test loss 4.832192, test error 54.03
# Epoch   400, train loss 0.009833, train error 0.00,  test loss 5.561816, test error 54.25
# Epoch   500, train loss 0.006201, train error 0.00,  test loss 6.028089, test error 54.45
# Epoch   600, train loss 0.004416, train error 0.00,  test loss 6.373637, test error 54.55
# Epoch   700, train loss 0.003410, train error 0.00,  test loss 6.653547, test error 54.67
# Epoch   800, train loss 0.002728, train error 0.00,  test loss 6.877110, test error 54.53
# Epoch   900, train loss 0.002266, train error 0.00,  test loss 7.069442, test error 54.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.024389, train error 75.12,  test loss 1.979783, test error 75.35
# Epoch   100, train loss 0.391468, train error 10.30,  test loss 1.891966, test error 51.58
# Epoch   200, train loss 0.038413, train error 0.00,  test loss 3.531178, test error 52.47
# Epoch   300, train loss 0.011765, train error 0.00,  test loss 4.367703, test error 52.70
# Epoch   400, train loss 0.006332, train error 0.00,  test loss 4.829916, test error 52.70
# Epoch   500, train loss 0.004209, train error 0.00,  test loss 5.142279, test error 52.90
# Epoch   600, train loss 0.003096, train error 0.00,  test loss 5.383250, test error 53.00
# Epoch   700, train loss 0.002426, train error 0.00,  test loss 5.579572, test error 52.83
# Epoch   800, train loss 0.001975, train error 0.00,  test loss 5.742548, test error 52.75
# Epoch   900, train loss 0.001657, train error 0.00,  test loss 5.881263, test error 52.72
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019515, train error 76.00,  test loss 1.941193, test error 75.75
# Epoch   100, train loss 0.262565, train error 4.45,  test loss 2.068774, test error 51.40
# Epoch   200, train loss 0.022555, train error 0.00,  test loss 3.475032, test error 51.83
# Epoch   300, train loss 0.008588, train error 0.00,  test loss 4.063777, test error 52.12
# Epoch   400, train loss 0.005000, train error 0.00,  test loss 4.410161, test error 52.03
# Epoch   500, train loss 0.003422, train error 0.00,  test loss 4.652637, test error 52.03
# Epoch   600, train loss 0.002566, train error 0.00,  test loss 4.837715, test error 52.15
# Epoch   700, train loss 0.002032, train error 0.00,  test loss 4.987597, test error 52.25
# Epoch   800, train loss 0.001671, train error 0.00,  test loss 5.114331, test error 52.20
# Epoch   900, train loss 0.001411, train error 0.00,  test loss 5.224450, test error 52.08
# Training model with  90 hidden variables
# Epoch     0, train loss 2.016160, train error 74.10,  test loss 1.965334, test error 75.30
# Epoch   100, train loss 0.147908, train error 1.30,  test loss 2.235396, test error 52.35
# Epoch   200, train loss 0.015114, train error 0.00,  test loss 3.282776, test error 52.28
# Epoch   300, train loss 0.006632, train error 0.00,  test loss 3.739172, test error 52.62
# Epoch   400, train loss 0.004037, train error 0.00,  test loss 4.016009, test error 52.95
# Epoch   500, train loss 0.002825, train error 0.00,  test loss 4.208225, test error 52.88
# Epoch   600, train loss 0.002146, train error 0.00,  test loss 4.363313, test error 52.92
# Epoch   700, train loss 0.001713, train error 0.00,  test loss 4.488526, test error 53.17
# Epoch   800, train loss 0.001417, train error 0.00,  test loss 4.594486, test error 53.35
# Epoch   900, train loss 0.001203, train error 0.00,  test loss 4.687102, test error 53.35
# Training model with 100 hidden variables
# Epoch     0, train loss 1.978959, train error 72.45,  test loss 1.901519, test error 73.25
# Epoch   100, train loss 0.105307, train error 0.43,  test loss 2.175383, test error 50.67
# Epoch   200, train loss 0.012182, train error 0.00,  test loss 3.004083, test error 50.30
# Epoch   300, train loss 0.005647, train error 0.00,  test loss 3.366931, test error 50.70
# Epoch   400, train loss 0.003514, train error 0.00,  test loss 3.590479, test error 50.67
# Epoch   500, train loss 0.002494, train error 0.00,  test loss 3.752281, test error 50.53
# Epoch   600, train loss 0.001909, train error 0.00,  test loss 3.880987, test error 50.58
# Epoch   700, train loss 0.001533, train error 0.00,  test loss 3.985757, test error 50.70
# Epoch   800, train loss 0.001274, train error 0.00,  test loss 4.074954, test error 50.78
# Epoch   900, train loss 0.001085, train error 0.00,  test loss 4.151730, test error 50.60
# Training model with 120 hidden variables
# Epoch     0, train loss 1.990405, train error 73.00,  test loss 1.919801, test error 74.20
# Epoch   100, train loss 0.056952, train error 0.03,  test loss 2.163709, test error 48.62
# Epoch   200, train loss 0.009833, train error 0.00,  test loss 2.745846, test error 48.53
# Epoch   300, train loss 0.004832, train error 0.00,  test loss 3.013779, test error 48.67
# Epoch   400, train loss 0.003072, train error 0.00,  test loss 3.183743, test error 48.72
# Epoch   500, train loss 0.002211, train error 0.00,  test loss 3.307323, test error 48.65
# Epoch   600, train loss 0.001706, train error 0.00,  test loss 3.405160, test error 48.60
# Epoch   700, train loss 0.001379, train error 0.00,  test loss 3.485881, test error 48.60
# Epoch   800, train loss 0.001151, train error 0.00,  test loss 3.555049, test error 48.65
# Epoch   900, train loss 0.000983, train error 0.00,  test loss 3.615653, test error 48.50
# Training model with 140 hidden variables
# Epoch     0, train loss 1.972397, train error 73.12,  test loss 1.918716, test error 74.10
# Epoch   100, train loss 0.037109, train error 0.00,  test loss 2.225884, test error 50.22
# Epoch   200, train loss 0.008328, train error 0.00,  test loss 2.711169, test error 50.25
# Epoch   300, train loss 0.004277, train error 0.00,  test loss 2.947704, test error 50.22
# Epoch   400, train loss 0.002775, train error 0.00,  test loss 3.102771, test error 50.33
# Epoch   500, train loss 0.002015, train error 0.00,  test loss 3.217948, test error 50.17
# Epoch   600, train loss 0.001566, train error 0.00,  test loss 3.309834, test error 50.25
# Epoch   700, train loss 0.001271, train error 0.00,  test loss 3.386523, test error 50.33
# Epoch   800, train loss 0.001064, train error 0.00,  test loss 3.451628, test error 50.35
# Epoch   900, train loss 0.000911, train error 0.00,  test loss 3.508488, test error 50.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.951658, train error 72.70,  test loss 1.876953, test error 74.00
# Epoch   100, train loss 0.028628, train error 0.00,  test loss 2.094969, test error 48.65
# Epoch   200, train loss 0.007223, train error 0.00,  test loss 2.501335, test error 48.53
# Epoch   300, train loss 0.003796, train error 0.00,  test loss 2.699604, test error 48.92
# Epoch   400, train loss 0.002495, train error 0.00,  test loss 2.830593, test error 48.92
# Epoch   500, train loss 0.001826, train error 0.00,  test loss 2.929458, test error 48.75
# Epoch   600, train loss 0.001425, train error 0.00,  test loss 3.005615, test error 48.75
# Epoch   700, train loss 0.001161, train error 0.00,  test loss 3.071724, test error 48.75
# Epoch   800, train loss 0.000975, train error 0.00,  test loss 3.127147, test error 48.75
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.175738, test error 48.75
# Training model with 180 hidden variables
# Epoch     0, train loss 1.938379, train error 72.32,  test loss 1.892149, test error 73.50
# Epoch   100, train loss 0.025408, train error 0.00,  test loss 2.132041, test error 49.40
# Epoch   200, train loss 0.006672, train error 0.00,  test loss 2.513165, test error 49.65
# Epoch   300, train loss 0.003568, train error 0.00,  test loss 2.701701, test error 49.70
# Epoch   400, train loss 0.002359, train error 0.00,  test loss 2.827984, test error 49.72
# Epoch   500, train loss 0.001735, train error 0.00,  test loss 2.923245, test error 49.75
# Epoch   600, train loss 0.001358, train error 0.00,  test loss 2.998704, test error 49.78
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 3.061438, test error 49.75
# Epoch   800, train loss 0.000932, train error 0.00,  test loss 3.115146, test error 49.72
# Epoch   900, train loss 0.000801, train error 0.00,  test loss 3.162107, test error 49.58
# Training model with 200 hidden variables
# Epoch     0, train loss 1.923707, train error 70.35,  test loss 1.839621, test error 70.12
# Epoch   100, train loss 0.021520, train error 0.00,  test loss 2.061036, test error 48.40
# Epoch   200, train loss 0.006146, train error 0.00,  test loss 2.397953, test error 48.50
# Epoch   300, train loss 0.003345, train error 0.00,  test loss 2.568207, test error 48.38
# Epoch   400, train loss 0.002230, train error 0.00,  test loss 2.682845, test error 48.30
# Epoch   500, train loss 0.001648, train error 0.00,  test loss 2.769827, test error 48.35
# Epoch   600, train loss 0.001295, train error 0.00,  test loss 2.840209, test error 48.35
# Epoch   700, train loss 0.001059, train error 0.00,  test loss 2.898957, test error 48.17
# Epoch   800, train loss 0.000893, train error 0.00,  test loss 2.949479, test error 48.15
# Epoch   900, train loss 0.000768, train error 0.00,  test loss 2.993145, test error 48.05
# Training model with 250 hidden variables
# Epoch     0, train loss 1.893649, train error 69.40,  test loss 1.819960, test error 70.95
# Epoch   100, train loss 0.017693, train error 0.00,  test loss 1.902998, test error 46.90
# Epoch   200, train loss 0.005488, train error 0.00,  test loss 2.159393, test error 46.70
# Epoch   300, train loss 0.003035, train error 0.00,  test loss 2.290835, test error 46.67
# Epoch   400, train loss 0.002044, train error 0.00,  test loss 2.382563, test error 46.58
# Epoch   500, train loss 0.001519, train error 0.00,  test loss 2.451492, test error 46.58
# Epoch   600, train loss 0.001197, train error 0.00,  test loss 2.506851, test error 46.55
# Epoch   700, train loss 0.000982, train error 0.00,  test loss 2.553919, test error 46.58
# Epoch   800, train loss 0.000829, train error 0.00,  test loss 2.593356, test error 46.62
# Epoch   900, train loss 0.000714, train error 0.00,  test loss 2.628340, test error 46.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876607, train error 68.10,  test loss 1.801221, test error 69.32
# Epoch   100, train loss 0.014466, train error 0.00,  test loss 1.863410, test error 46.47
# Epoch   200, train loss 0.004822, train error 0.00,  test loss 2.077088, test error 45.88
# Epoch   300, train loss 0.002735, train error 0.00,  test loss 2.197175, test error 45.88
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.277573, test error 46.00
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.340333, test error 46.00
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.390592, test error 46.03
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.433102, test error 46.00
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.469751, test error 46.00
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.501828, test error 45.97
# Training model with 400 hidden variables
# Epoch     0, train loss 1.849436, train error 66.70,  test loss 1.778213, test error 68.97
# Epoch   100, train loss 0.011777, train error 0.00,  test loss 1.718305, test error 45.47
# Epoch   200, train loss 0.004202, train error 0.00,  test loss 1.882839, test error 45.42
# Epoch   300, train loss 0.002431, train error 0.00,  test loss 1.974929, test error 45.35
# Epoch   400, train loss 0.001674, train error 0.00,  test loss 2.039324, test error 45.20
# Epoch   500, train loss 0.001261, train error 0.00,  test loss 2.089027, test error 45.12
# Epoch   600, train loss 0.001004, train error 0.00,  test loss 2.129067, test error 45.10
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.163079, test error 45.22
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.192244, test error 45.17
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.217440, test error 45.20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
